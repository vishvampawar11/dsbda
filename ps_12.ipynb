# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/Adult/adult.csv")

# %%
df
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0         Exec-managerial         Husband   White     Male      0   0   13
# 1       Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2       Handlers-cleaners         Husband   Black     Male      0   0   40
# 3          Prof-specialty            Wife   Black   Female      0   0   40
# 4         Exec-managerial            Wife   White   Female      0   0   40
# ...                   ...             ...     ...      ...    ...  ..  ...
# 32555        Tech-support            Wife   White   Female      0   0   38
# 32556   Machine-op-inspct         Husband   White     Male      0   0   40
# 32557        Adm-clerical       Unmarried   White   Female      0   0   40
# 32558        Adm-clerical       Own-child   White     Male      0   0   20
# 32559     Exec-managerial            Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3                Cuba   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K
#
# [32560 rows x 15 columns]

# %%
first_row = df.columns

# %%
headers = ['age',
           'workclass',
           'fnlwgt',
           'education',
           'education-num',
           'marital-status',
           'occupation',
           'relationship',
           'race',
           'sex',
           'capital-gain', 
           'capital-loss',
           'hours-per-week',
           'native-country',
           '<=50K'
          ]

# %%
df.columns = headers

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#         <=50K
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# <=50K             0
# dtype: int64

# %% [markdown]
# <h3>1. Create data subsets for different Country, Sex, Race</h3>

# %% [markdown]
# <h4>Country</h4>

# %%
df = df[df['native-country'] != ' ?']

# %%
countries = df['native-country'].unique()
countries
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
country_dfs = []

for country in countries:
    country_dfs.append(df[df['native-country'] == country])

# %%
country_dfs_dict = dict(zip(countries, country_dfs))
country_dfs_dict
# Out:
# {' United-States':        age          workclass  fnlwgt    education  education-num  \
#  0       50   Self-emp-not-inc   83311    Bachelors             13
#  1       38            Private  215646      HS-grad              9
#  2       53            Private  234721         11th              7
#  4       37            Private  284582      Masters             14
#  6       52   Self-emp-not-inc  209642      HS-grad              9
#  ...    ...                ...     ...          ...            ...
#  32555   27            Private  257302   Assoc-acdm             12
#  32556   40            Private  154374      HS-grad              9
#  32557   58            Private  151910      HS-grad              9
#  32558   22            Private  201490      HS-grad              9
#  32559   52       Self-emp-inc  287927      HS-grad              9
#
#              marital-status          occupation    relationship    race  \
#  0       Married-civ-spouse     Exec-managerial         Husband   White
#  1                 Divorced   Handlers-cleaners   Not-in-family   White
#  2       Married-civ-spouse   Handlers-cleaners         Husband   Black
#  4       Married-civ-spouse     Exec-managerial            Wife   White
#  6       Married-civ-spouse     Exec-managerial         Husband   White
#  ...                    ...                 ...             ...     ...
#  32555   Married-civ-spouse        Tech-support            Wife   White
#  32556   Married-civ-spouse   Machine-op-inspct         Husband   White
#  32557              Widowed        Adm-clerical       Unmarried   White
#  32558        Never-married        Adm-clerical       Own-child   White
#  32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#             sex  capital-gain  capital-loss  hours-per-week  native-country  \
#  0         Male             0             0              13   United-States
#  1         Male             0             0              40   United-States
#  2         Male             0             0              40   United-States
#  4       Female             0             0              40   United-States
#  6         Male             0             0              45   United-States
#  ...        ...           ...           ...             ...             ...
#  32555   Female             0             0              38   United-States
#  32556     Male             0             0              40   United-States
#  32557   Female             0             0              40   United-States
#  32558     Male             0             0              20   United-States
#  32559   Female         15024             0              40   United-States
#
#          <=50K
#  0       <=50K
#  1       <=50K
#  2       <=50K
#  4       <=50K
#  6        >50K
#  ...       ...
#  32555   <=50K
#  32556    >50K
#  32557   <=50K
#  32558   <=50K
#  32559    >50K
#
#  [29169 rows x 15 columns],
#  ' Cuba':        age          workclass  fnlwgt   education  education-num  \
#  3       28            Private  338409   Bachelors             13
#  80      52            Private  276515   Bachelors             13
#  637     47       Self-emp-inc  248145     5th-6th              3
#  700     31            Private  243605   Bachelors             13
#  1236    41   Self-emp-not-inc  209344     HS-grad              9
#  ...    ...                ...     ...         ...            ...
#  30840   37            Private  238433     1st-4th              2
#  30891   52            Private  222646        12th              8
#  30905   39   Self-emp-not-inc  251323         9th              5
#  31148   52       Self-emp-inc  230767   Bachelors             13
#  31906   48            Private  379883     Masters             14
#
#              marital-status          occupation     relationship    race  \
#  3       Married-civ-spouse      Prof-specialty             Wife   Black
#  80      Married-civ-spouse       Other-service          Husband   White
#  637     Married-civ-spouse    Transport-moving          Husband   White
#  700                Widowed               Sales        Unmarried   White
#  1236    Married-civ-spouse               Sales   Other-relative   White
#  ...                    ...                 ...              ...     ...
#  30840   Married-civ-spouse    Transport-moving          Husband   White
#  30891            Separated   Machine-op-inspct   Other-relative   White
#  30905   Married-civ-spouse     Farming-fishing   Other-relative   White
#  31148   Married-civ-spouse     Exec-managerial          Husband   White
#  31906   Married-civ-spouse      Prof-specialty          Husband   White
#
#             sex  capital-gain  capital-loss  hours-per-week native-country  \
#  3       Female             0             0              40           Cuba
#  80        Male             0             0              40           Cuba
#  637       Male             0             0              50           Cuba
#  700     Female             0          1380              40           Cuba
#  1236    Female             0             0              40           Cuba
#  ...        ...           ...           ...             ...            ...
#  30840     Male             0             0              40           Cuba
#  30891   Female             0             0              40           Cuba
#  30905     Male             0             0              40           Cuba
#  31148     Male             0          1902              60           Cuba
#  31906     Male             0             0              40           Cuba
#
#          <=50K
#  3       <=50K
#  80      <=50K
#  637     <=50K
#  700     <=50K
#  1236    <=50K
#  ...       ...
#  30840   <=50K
#  30891   <=50K
#  30905   <=50K
#  31148    >50K
#  31906    >50K
#
#  [95 rows x 15 columns],
#  ' Jamaica':        age workclass  fnlwgt      education  education-num  \
#  5       49   Private  160187            9th              5
#  705     40   Private  229148           12th              8
#  1134    31   Private  184307   Some-college             10
#  1569    19         ?   62534      Bachelors             13
#  2005    57   Private  185072   Some-college             10
#  ...    ...       ...     ...            ...            ...
#  30862   46   Private  169324        HS-grad              9
#  31032   55   Private  132887        HS-grad              9
#  31037   33   Private  202642      Bachelors             13
#  31953   34   Private  111589           10th              6
#  32228   22   Private  254547   Some-college             10
#
#                 marital-status         occupation     relationship    race  \
#  5       Married-spouse-absent      Other-service    Not-in-family   Black
#  705        Married-civ-spouse      Other-service          Husband   Black
#  1134       Married-civ-spouse    Exec-managerial          Husband   White
#  1569            Never-married                  ?        Own-child   Black
#  2005            Never-married       Adm-clerical   Other-relative   Black
#  ...                       ...                ...              ...     ...
#  30862               Separated      Other-service    Not-in-family   Black
#  31032      Married-civ-spouse   Transport-moving          Husband   Black
#  31037               Separated     Prof-specialty   Other-relative   Black
#  31953           Never-married      Other-service        Unmarried   Black
#  32228           Never-married    Exec-managerial        Unmarried   Black
#
#             sex  capital-gain  capital-loss  hours-per-week native-country  \
#  5       Female             0             0              16        Jamaica
#  705       Male             0             0              40        Jamaica
#  1134      Male             0             0              50        Jamaica
#  1569    Female             0             0              40        Jamaica
#  2005    Female             0             0              40        Jamaica
#  ...        ...           ...           ...             ...            ...
#  30862   Female             0             0              45        Jamaica
#  31032     Male          3411             0              40        Jamaica
#  31037   Female             0             0              40        Jamaica
#  31953   Female             0             0              40        Jamaica
#  32228   Female             0             0              40        Jamaica
#
#          <=50K
#  5       <=50K
#  705     <=50K
#  1134     >50K
#  1569    <=50K
#  2005    <=50K
#  ...       ...
#  30862   <=50K
#  31032   <=50K
#  31037   <=50K
#  31953   <=50K
#  32228   <=50K
#
#  [81 rows x 15 columns],
#  ' India':        age          workclass  fnlwgt    education  education-num  \
#  10      30          State-gov  141297    Bachelors             13
#  891     28            Private  164170    Assoc-voc             11
#  967     48            Private  164966    Bachelors             13
#  1028    48       Self-emp-inc  138370      Masters             14
#  1094    22   Self-emp-not-inc  361280    Bachelors             13
#  ...    ...                ...     ...          ...            ...
#  30151   48            Private  119471    Doctorate             16
#  30832   25            Private  110978   Assoc-acdm             12
#  30870   26            Private  160261      Masters             14
#  31326   38          State-gov  125499    Bachelors             13
#  31356   23            Private  143003      Masters             14
#
#                 marital-status        occupation    relationship  \
#  10         Married-civ-spouse    Prof-specialty         Husband
#  891        Married-civ-spouse      Adm-clerical            Wife
#  967        Married-civ-spouse   Exec-managerial         Husband
#  1028    Married-spouse-absent             Sales   Not-in-family
#  1094            Never-married    Prof-specialty       Own-child
#  ...                       ...               ...             ...
#  30151      Married-civ-spouse    Prof-specialty         Husband
#  30832      Married-civ-spouse      Adm-clerical            Wife
#  30870           Never-married    Prof-specialty   Not-in-family
#  31326      Married-civ-spouse    Prof-specialty         Husband
#  31356      Married-civ-spouse    Prof-specialty         Husband
#
#                        race      sex  capital-gain  capital-loss  \
#  10      Asian-Pac-Islander     Male             0             0
#  891     Asian-Pac-Islander   Female             0             0
#  967     Asian-Pac-Islander     Male             0             0
#  1028    Asian-Pac-Islander     Male             0             0
#  1094    Asian-Pac-Islander     Male             0             0
#  ...                    ...      ...           ...           ...
#  30151   Asian-Pac-Islander     Male             0             0
#  30832   Asian-Pac-Islander   Female             0             0
#  30870   Asian-Pac-Islander     Male             0             0
#  31326   Asian-Pac-Islander     Male          7688             0
#  31356   Asian-Pac-Islander     Male             0          1887
#
#         hours-per-week native-country   <=50K
#  10                 40          India    >50K
#  891                40          India   <=50K
#  967                40          India    >50K
#  1028               50          India   <=50K
#  1094               20          India   <=50K
#  ...               ...            ...     ...
#  30151              40          India    >50K
#  30832              37          India    >50K
#  30870              20          India   <=50K
#  31326              60          India    >50K
#  31356              50          India    >50K
#
#  [100 rows x 15 columns],
#  ' Mexico':        age   workclass  fnlwgt      education  education-num  \
#  14      34     Private  245487        7th-8th              4
#  55      46     Private  216666        5th-6th              3
#  74      27     Private  213921        HS-grad              9
#  141     19     Private  316868   Some-college             10
#  149     47   Local-gov  186009   Some-college             10
#  ...    ...         ...     ...            ...            ...
#  32331   26     Private  233777        HS-grad              9
#  32333   24     Private  176580        5th-6th              3
#  32424   23     Private  180771        1st-4th              2
#  32431   36     Private  208068      Preschool              1
#  32546   43     Private  260761        HS-grad              9
#
#                 marital-status          occupation    relationship  \
#  14         Married-civ-spouse    Transport-moving         Husband
#  55         Married-civ-spouse   Machine-op-inspct         Husband
#  74              Never-married       Other-service       Own-child
#  141             Never-married       Other-service       Own-child
#  149                  Divorced        Adm-clerical       Unmarried
#  ...                       ...                 ...             ...
#  32331      Married-civ-spouse        Craft-repair         Husband
#  32333   Married-spouse-absent     Farming-fishing   Not-in-family
#  32424      Married-civ-spouse   Machine-op-inspct            Wife
#  32431                Divorced       Other-service   Not-in-family
#  32546      Married-civ-spouse   Machine-op-inspct         Husband
#
#                        race      sex  capital-gain  capital-loss  \
#  14      Amer-Indian-Eskimo     Male             0             0
#  55                   White     Male             0             0
#  74                   White     Male             0             0
#  141                  White     Male             0             0
#  149                  White   Female             0             0
#  ...                    ...      ...           ...           ...
#  32331                White     Male             0             0
#  32333                White     Male             0             0
#  32424   Amer-Indian-Eskimo   Female             0             0
#  32431                Other     Male             0             0
#  32546                White     Male             0             0
#
#         hours-per-week native-country   <=50K
#  14                 45         Mexico   <=50K
#  55                 40         Mexico   <=50K
#  74                 40         Mexico   <=50K
#  141                30         Mexico   <=50K
#  149                38         Mexico   <=50K
#  ...               ...            ...     ...
#  32331              72         Mexico   <=50K
#  32333              40         Mexico   <=50K
#  32424              35         Mexico   <=50K
#  32431              72         Mexico   <=50K
#  32546              40         Mexico   <=50K
#
#  [643 rows x 15 columns],
#  ' South':        age          workclass  fnlwgt      education  education-num  \
#  26      54                  ?  180211   Some-college             10
#  667     20                  ?  114746           11th              7
#  915     43            Private  158926        Masters             14
#  1968    45   Self-emp-not-inc  133969        HS-grad              9
#  2207    34   Self-emp-not-inc  306982      Bachelors             13
#  ...    ...                ...     ...            ...            ...
#  29487   36            Private  162312        HS-grad              9
#  30346   39   Self-emp-not-inc  191342      Bachelors             13
#  30532   50   Self-emp-not-inc  131982        HS-grad              9
#  31301   60            Private   85995        Masters             14
#  31750   22                  ?  148955   Some-college             10
#
#                 marital-status        occupation    relationship  \
#  26         Married-civ-spouse                 ?         Husband
#  667     Married-spouse-absent                 ?       Own-child
#  915        Married-civ-spouse    Prof-specialty            Wife
#  1968       Married-civ-spouse             Sales         Husband
#  2207       Married-civ-spouse             Sales         Husband
#  ...                       ...               ...             ...
#  29487           Never-married      Craft-repair   Not-in-family
#  30346      Married-civ-spouse   Exec-managerial         Husband
#  30532      Married-civ-spouse     Other-service         Husband
#  31301      Married-civ-spouse      Adm-clerical         Husband
#  31750           Never-married                 ?       Own-child
#
#                        race      sex  capital-gain  capital-loss  \
#  26      Asian-Pac-Islander     Male             0             0
#  667     Asian-Pac-Islander   Female             0          1762
#  915     Asian-Pac-Islander   Female             0             0
#  1968    Asian-Pac-Islander     Male             0             0
#  2207    Asian-Pac-Islander     Male             0             0
#  ...                    ...      ...           ...           ...
#  29487   Asian-Pac-Islander     Male             0             0
#  30346   Asian-Pac-Islander     Male             0             0
#  30532   Asian-Pac-Islander     Male             0             0
#  31301   Asian-Pac-Islander     Male             0             0
#  31750   Asian-Pac-Islander   Female             0             0
#
#         hours-per-week native-country   <=50K
#  26                 60          South    >50K
#  667                40          South   <=50K
#  915                50          South   <=50K
#  1968               50          South    >50K
#  2207               60          South   <=50K
#  ...               ...            ...     ...
#  29487              70          South   <=50K
#  30346              50          South   <=50K
#  30532              60          South   <=50K
#  31301              50          South    >50K
#  31750              15          South   <=50K
#
#  [80 rows x 15 columns],
#  ' Puerto-Rico':        age workclass  fnlwgt      education  education-num  \
#  34      48   Private  242406           11th              7
#  56      35   Private   56352      Assoc-voc             11
#  403     28   Private  166481        7th-8th              4
#  529     44   Private  109339           11th              7
#  1788    66   Private  142723        5th-6th              3
#  ...    ...       ...     ...            ...            ...
#  28714   57         ?  202903        7th-8th              4
#  29014   35   Private  194960        HS-grad              9
#  29646   42   Private  251239   Some-college             10
#  30298   42   Private  152676        7th-8th              4
#  31056   33   Private  256062   Some-college             10
#
#                 marital-status          occupation    relationship    race  \
#  34              Never-married   Machine-op-inspct       Unmarried   White
#  56         Married-civ-spouse       Other-service         Husband   White
#  403        Married-civ-spouse   Handlers-cleaners         Husband   Other
#  529                  Divorced   Machine-op-inspct       Unmarried   Other
#  1788    Married-spouse-absent   Handlers-cleaners       Unmarried   White
#  ...                       ...                 ...             ...     ...
#  28714      Married-civ-spouse                   ?            Wife   White
#  29014           Never-married     Farming-fishing   Not-in-family   Other
#  29646      Married-civ-spouse     Exec-managerial         Husband   White
#  30298                Divorced        Craft-repair       Unmarried   White
#  31056           Never-married        Adm-clerical       Unmarried   White
#
#             sex  capital-gain  capital-loss  hours-per-week native-country  \
#  34        Male             0             0              40    Puerto-Rico
#  56        Male             0             0              40    Puerto-Rico
#  403       Male             0          2179              40    Puerto-Rico
#  529     Female             0             0              46    Puerto-Rico
#  1788    Female             0             0              40    Puerto-Rico
#  ...        ...           ...           ...             ...            ...
#  28714   Female          1173             0              45    Puerto-Rico
#  29014     Male             0             0              40    Puerto-Rico
#  29646     Male             0             0              40    Puerto-Rico
#  30298     Male             0             0              40    Puerto-Rico
#  31056   Female             0             0              35    Puerto-Rico
#
#          <=50K
#  34      <=50K
#  56      <=50K
#  403     <=50K
#  529     <=50K
#  1788    <=50K
#  ...       ...
#  28714   <=50K
#  29014   <=50K
#  29646   <=50K
#  30298   <=50K
#  31056   <=50K
#
#  [114 rows x 15 columns],
#  ' Honduras':        age          workclass  fnlwgt      education  education-num  \
#  51      47            Private   51835    Prof-school             15
#  713     36          Local-gov  382635      Bachelors             13
#  2083    28                  ?  308493        HS-grad              9
#  6957    47            Private  243904        HS-grad              9
#  7233    58          State-gov  136982        HS-grad              9
#  12422   26       Self-emp-inc  246025        HS-grad              9
#  16956   31            Private  306459        1st-4th              2
#  17560   18            Private  282609        5th-6th              3
#  25744   41       Self-emp-inc  146659   Some-college             10
#  27114   28            Private  411587   Some-college             10
#  27270   31            Private  244665   Some-college             10
#  27764   19            Private  298891           11th              7
#  32455   30   Self-emp-not-inc  261943           11th              7
#
#                 marital-status          occupation     relationship    race  \
#  51         Married-civ-spouse      Prof-specialty             Wife   White
#  713                  Divorced        Adm-clerical        Unmarried   White
#  2083       Married-civ-spouse                   ?             Wife   White
#  6957                 Divorced        Adm-clerical        Unmarried   White
#  7233    Married-spouse-absent       Other-service        Unmarried   Black
#  12422               Separated               Sales        Unmarried   White
#  16956               Separated   Handlers-cleaners        Unmarried   White
#  17560           Never-married   Handlers-cleaners   Other-relative   White
#  25744                Divorced   Machine-op-inspct    Not-in-family   White
#  27114           Never-married     Protective-serv        Own-child   White
#  27270           Never-married     Exec-managerial    Not-in-family   White
#  27764           Never-married               Sales    Not-in-family   White
#  32455   Married-spouse-absent        Craft-repair    Not-in-family   White
#
#             sex  capital-gain  capital-loss  hours-per-week native-country  \
#  51      Female             0          1902              60       Honduras
#  713     Female             0             0              35       Honduras
#  2083    Female             0             0              17       Honduras
#  6957      Male             0             0              40       Honduras
#  7233    Female             0             0              40       Honduras
#  12422   Female             0             0              20       Honduras
#  16956     Male             0             0              35       Honduras
#  17560     Male             0             0              30       Honduras
#  25744   Female             0             0              40       Honduras
#  27114     Male             0             0              40       Honduras
#  27270     Male             0             0              45       Honduras
#  27764   Female             0             0              40       Honduras
#  32455     Male             0             0              30       Honduras
#
#          <=50K
#  51       >50K
#  713     <=50K
#  2083    <=50K
#  6957    <=50K
#  7233    <=50K
#  12422   <=50K
#  16956   <=50K
#  17560   <=50K
#  25744   <=50K
#  27114   <=50K
#  27270   <=50K
#  27764   <=50K
#  32455   <=50K  ,
#  ' England':        age          workclass  fnlwgt    education  education-num  \
#  97      48            Private  171095   Assoc-acdm             12
#  162     28            Private   88419      HS-grad              9
#  798     43            Private  274363    Bachelors             13
#  1227    50            Private  358740      HS-grad              9
#  1513    59       Self-emp-inc  125000    Bachelors             13
#  ...    ...                ...     ...          ...            ...
#  28844   31            Private  272856      HS-grad              9
#  29441   21            Private  200089      1st-4th              2
#  30278   29            Private  375482    Bachelors             13
#  31337   46            Private  149640    Bachelors             13
#  31800   48   Self-emp-not-inc  218835      Masters             14
#
#              marital-status        occupation     relationship  \
#  97                Divorced   Exec-managerial        Unmarried
#  162          Never-married   Exec-managerial    Not-in-family
#  798     Married-civ-spouse   Exec-managerial          Husband
#  1227              Divorced      Adm-clerical        Unmarried
#  1513    Married-civ-spouse   Exec-managerial          Husband
#  ...                    ...               ...              ...
#  28844        Never-married      Craft-repair        Own-child
#  29441   Married-civ-spouse     Other-service   Other-relative
#  30278        Never-married    Prof-specialty    Not-in-family
#  31337             Divorced    Prof-specialty    Not-in-family
#  31800   Married-civ-spouse             Sales          Husband
#
#                        race      sex  capital-gain  capital-loss  \
#  97                   White   Female             0             0
#  162     Asian-Pac-Islander   Female             0             0
#  798                  White     Male             0          1902
#  1227                 White   Female             0             0
#  1513                 White     Male             0             0
#  ...                    ...      ...           ...           ...
#  28844                Black     Male             0             0
#  29441                White     Male             0             0
#  30278                White     Male             0             0
#  31337                White     Male             0             0
#  31800                White     Male             0             0
#
#         hours-per-week native-country   <=50K
#  97                 40        England   <=50K
#  162                40        England   <=50K
#  798                40        England    >50K
#  1227               40        England   <=50K
#  1513               40        England    >50K
#  ...               ...            ...     ...
#  28844              50        England   <=50K
#  29441              40        England   <=50K
#  30278              50        England   <=50K
#  31337              45        England    >50K
#  31800              50        England   <=50K
#
#  [90 rows x 15 columns],
#  ' Canada':        age          workclass  fnlwgt      education  education-num  \
#  111     56   Self-emp-not-inc  335605        HS-grad              9
#  265     19                  ?  218956   Some-college             10
#  592     31            Private  168387      Bachelors             13
#  1050    53   Self-emp-not-inc  263925      Bachelors             13
#  1313    32            Private  509350   Some-college             10
#  ...    ...                ...     ...            ...            ...
#  30287   40            Private  406811        HS-grad              9
#  30622   72                  ?  402306   Some-college             10
#  30968   51            Private  305673      Assoc-voc             11
#  32092   62                  ?  263374      Assoc-voc             11
#  32111   32       Self-emp-inc  209691      Bachelors             13
#
#              marital-status          occupation relationship    race      sex  \
#  111     Married-civ-spouse       Other-service      Husband   White     Male
#  265          Never-married                   ?    Own-child   White     Male
#  592     Married-civ-spouse      Prof-specialty      Husband   White     Male
#  1050    Married-civ-spouse               Sales      Husband   White     Male
#  1313    Married-civ-spouse   Handlers-cleaners      Husband   White     Male
#  ...                    ...                 ...          ...     ...      ...
#  30287            Separated     Exec-managerial    Unmarried   White   Female
#  30622   Married-civ-spouse                   ?      Husband   White     Male
#  30968   Married-civ-spouse        Craft-repair      Husband   White     Male
#  32092   Married-civ-spouse                   ?      Husband   White     Male
#  32111   Married-civ-spouse        Craft-repair      Husband   White     Male
#
#         capital-gain  capital-loss  hours-per-week native-country   <=50K
#  111               0          1887              50         Canada    >50K
#  265               0             0              24         Canada   <=50K
#  592            7688             0              40         Canada    >50K
#  1050              0             0              40         Canada    >50K
#  1313              0             0              50         Canada    >50K
#  ...             ...           ...             ...            ...     ...
#  30287             0             0              40         Canada   <=50K
#  30622             0             0              32         Canada   <=50K
#  30968             0             0              40         Canada    >50K
#  32092             0             0              40         Canada   <=50K
#  32111             0             0              50         Canada   <=50K
#
#  [121 rows x 15 columns],
#  ' Germany':        age          workclass  fnlwgt      education  education-num  \
#  121     30            Private   77143      Bachelors             13
#  279     22            Private   34918      Bachelors             13
#  766     22            Private  151790   Some-college             10
#  1008    26            Private  109186   Some-college             10
#  1141    59        Federal-gov  212448        HS-grad              9
#  ...    ...                ...     ...            ...            ...
#  32073   30            Private  318749      Assoc-voc             11
#  32100   45            Private  174794      Bachelors             13
#  32140   34            Private  193344   Some-college             10
#  32235   26            Private  323044   Some-college             10
#  32340   74   Self-emp-not-inc  199136      Bachelors             13
#
#              marital-status        occupation    relationship    race      sex  \
#  121          Never-married   Exec-managerial       Own-child   Black     Male
#  279          Never-married    Prof-specialty   Not-in-family   White   Female
#  766     Married-civ-spouse             Sales            Wife   White   Female
#  1008    Married-civ-spouse             Sales         Husband   White     Male
#  1141               Widowed             Sales       Unmarried   White   Female
#  ...                    ...               ...             ...     ...      ...
#  32073   Married-civ-spouse      Tech-support            Wife   White   Female
#  32100            Separated    Prof-specialty       Unmarried   White   Female
#  32140        Never-married      Adm-clerical       Unmarried   White   Female
#  32235   Married-civ-spouse   Exec-managerial         Husband   White     Male
#  32340              Widowed      Craft-repair   Not-in-family   White     Male
#
#         capital-gain  capital-loss  hours-per-week native-country   <=50K
#  121               0             0              40        Germany   <=50K
#  279               0             0              15        Germany   <=50K
#  766               0             0              30        Germany   <=50K
#  1008              0             0              50        Germany   <=50K
#  1141              0             0              40        Germany   <=50K
#  ...             ...           ...             ...            ...     ...
#  32073             0             0              35        Germany   <=50K
#  32100             0             0              56        Germany   <=50K
#  32140             0             0              40        Germany   <=50K
#  32235             0             0              45        Germany    >50K
#  32340         15831             0               8        Germany    >50K
#
#  [137 rows x 15 columns],
#  ' Iran':        age          workclass  fnlwgt      education  education-num  \
#  134     38        Federal-gov  125933        Masters             14
#  236     41            Private  180138      Bachelors             13
#  347     56            Private  101128     Assoc-acdm             12
#  1053    38            Private  193026   Some-college             10
#  1386    40   Self-emp-not-inc  266324   Some-college             10
#  2651    34            Private  213226      Bachelors             13
#  3388    51            Private  293196      Doctorate             16
#  3389    45            Private  214627      Doctorate             16
#  4144    36            Private   95654      Bachelors             13
#  4368    22                  ?  211968   Some-college             10
#  4432    52          State-gov  149650      Doctorate             16
#  5204    30            Private  158420      Bachelors             13
#  6181    29          Local-gov  183523   Some-college             10
#  6294    40       Self-emp-inc  157240        Masters             14
#  6526    36            Private   82743     Assoc-acdm             12
#  6603    41            Private  406603        HS-grad              9
#  6749    34            Private  454508      Bachelors             13
#  6864    22            Private  190483   Some-college             10
#  7401    30   Self-emp-not-inc  176185     Assoc-acdm             12
#  7460    32        Federal-gov  148138      Bachelors             13
#  9825    33            Private  181091      Bachelors             13
#  9944    63            Private  213945      Bachelors             13
#  10124   47   Self-emp-not-inc  182752        HS-grad              9
#  13960   35            Private  202950        HS-grad              9
#  14143   57   Self-emp-not-inc  138285     Assoc-acdm             12
#  14697   44            Private  182629        Masters             14
#  15876   37            Private   79586      Bachelors             13
#  16090   43            Private  186188   Some-college             10
#  17853   36   Self-emp-not-inc  202950      Bachelors             13
#  19096   62          Local-gov  167889      Doctorate             16
#  19321   39   Self-emp-not-inc  315640      Bachelors             13
#  20242   37            Private  109133        Masters             14
#  20886   24            Private  122166   Some-college             10
#  21440   32   Self-emp-not-inc  180303      Bachelors             13
#  23320   23            Private  216181   Some-college             10
#  25171   47   Self-emp-not-inc  190072   Some-college             10
#  25645   36            Private   52327        Masters             14
#  25960   38            Private  136629      Bachelors             13
#  26544   32       Self-emp-inc  124919      Bachelors             13
#  26569   47            Private  192793      Doctorate             16
#  31002   35            Private  267866        HS-grad              9
#  31591   59            Private   59469        Masters             14
#  31984   42   Self-emp-not-inc  126614      Bachelors             13
#
#                 marital-status          occupation     relationship  \
#  134        Married-civ-spouse      Prof-specialty          Husband
#  236        Married-civ-spouse     Exec-managerial          Husband
#  347     Married-spouse-absent       Other-service    Not-in-family
#  1053                 Divorced        Craft-repair    Not-in-family
#  1386                 Divorced     Exec-managerial   Other-relative
#  2651       Married-civ-spouse      Prof-specialty          Husband
#  3388       Married-civ-spouse      Prof-specialty          Husband
#  3389                  Widowed      Prof-specialty        Unmarried
#  4144       Married-civ-spouse      Prof-specialty             Wife
#  4368            Never-married                   ?        Own-child
#  4432       Married-civ-spouse      Prof-specialty          Husband
#  5204            Never-married      Prof-specialty    Not-in-family
#  6181            Never-married     Exec-managerial    Not-in-family
#  6294       Married-civ-spouse     Exec-managerial             Wife
#  6526            Never-married    Transport-moving    Not-in-family
#  6603            Never-married       Other-service    Not-in-family
#  6749       Married-civ-spouse      Prof-specialty          Husband
#  6864                 Divorced               Sales        Own-child
#  7401       Married-civ-spouse               Sales          Husband
#  7460       Married-civ-spouse      Prof-specialty          Husband
#  9825       Married-civ-spouse        Adm-clerical          Husband
#  9944       Married-civ-spouse               Sales          Husband
#  10124      Married-civ-spouse        Adm-clerical             Wife
#  13960      Married-civ-spouse     Exec-managerial          Husband
#  14143      Married-civ-spouse       Other-service          Husband
#  14697                Divorced               Sales    Not-in-family
#  15876      Married-civ-spouse     Exec-managerial          Husband
#  16090                Divorced     Exec-managerial        Unmarried
#  17853      Married-civ-spouse     Exec-managerial          Husband
#  19096                 Widowed      Prof-specialty        Unmarried
#  19321           Never-married               Sales        Own-child
#  20242               Separated     Exec-managerial    Not-in-family
#  20886           Never-married        Adm-clerical        Own-child
#  21440                Divorced        Craft-repair        Unmarried
#  23320           Never-married               Sales        Own-child
#  25171      Married-civ-spouse        Craft-repair          Husband
#  25645      Married-civ-spouse      Prof-specialty          Husband
#  25960      Married-civ-spouse   Machine-op-inspct          Husband
#  26544      Married-civ-spouse       Other-service          Husband
#  26569      Married-civ-spouse      Prof-specialty          Husband
#  31002      Married-civ-spouse               Sales          Husband
#  31591      Married-civ-spouse        Tech-support          Husband
#  31984                Divorced     Exec-managerial    Not-in-family
#
#                        race      sex  capital-gain  capital-loss  \
#  134                  White     Male             0             0
#  236                  White     Male             0             0
#  347                  White     Male             0             0
#  1053                 White     Male             0             0
#  1386                 White     Male             0          1564
#  2651                 White     Male             0             0
#  3388                 White     Male         15024             0
#  3389                 White     Male         15020             0
#  4144                 White   Female             0             0
#  4368                 White   Female             0             0
#  4432                 White     Male             0             0
#  5204                 White     Male             0             0
#  6181                 White     Male             0             0
#  6294                 White   Female         15024             0
#  6526                 White     Male             0             0
#  6603                 White     Male             0             0
#  6749                 White     Male             0             0
#  6864                 White   Female             0             0
#  7401                 White     Male             0             0
#  7460    Asian-Pac-Islander     Male             0          2002
#  9825                 White     Male             0             0
#  9944                 White     Male         15024             0
#  10124                White   Female             0             0
#  13960                White     Male             0             0
#  14143                White     Male             0             0
#  14697                White     Male             0             0
#  15876   Asian-Pac-Islander     Male             0             0
#  16090                White   Female             0             0
#  17853                White     Male             0             0
#  19096                White   Female             0             0
#  19321   Asian-Pac-Islander     Male             0             0
#  20242                White     Male         27828             0
#  20886                White   Female             0             0
#  21440   Asian-Pac-Islander     Male             0             0
#  23320                White     Male             0             0
#  25171                White     Male             0             0
#  25645                Other     Male             0             0
#  25960                White     Male             0             0
#  26544   Asian-Pac-Islander     Male             0             0
#  26569                White     Male             0             0
#  31002   Asian-Pac-Islander     Male             0          1887
#  31591                White     Male             0             0
#  31984                Other     Male             0             0
#
#         hours-per-week native-country   <=50K
#  134                40           Iran    >50K
#  236                50           Iran    >50K
#  347                25           Iran   <=50K
#  1053               40           Iran   <=50K
#  1386               70           Iran    >50K
#  2651               40           Iran    >50K
#  3388               60           Iran    >50K
#  3389               40           Iran    >50K
#  4144               50           Iran    >50K
#  4368               40           Iran   <=50K
#  4432               40           Iran    >50K
#  5204               50           Iran   <=50K
#  6181               40           Iran   <=50K
#  6294               30           Iran    >50K
#  6526               55           Iran   <=50K
#  6603                6           Iran   <=50K
#  6749               65           Iran   <=50K
#  6864               48           Iran   <=50K
#  7401               60           Iran   <=50K
#  7460               40           Iran   <=50K
#  9825               60           Iran    >50K
#  9944               40           Iran    >50K
#  10124              35           Iran   <=50K
#  13960              55           Iran    >50K
#  14143              40           Iran   <=50K
#  14697              24           Iran   <=50K
#  15876              40           Iran   <=50K
#  16090              45           Iran   <=50K
#  17853              50           Iran   <=50K
#  19096              40           Iran   <=50K
#  19321              60           Iran   <=50K
#  20242              60           Iran    >50K
#  20886              40           Iran   <=50K
#  21440              47           Iran   <=50K
#  23320              36           Iran   <=50K
#  25171              40           Iran    >50K
#  25645              40           Iran    >50K
#  25960              40           Iran   <=50K
#  26544              50           Iran    >50K
#  26569              40           Iran    >50K
#  31002              50           Iran    >50K
#  31591              40           Iran   <=50K
#  31984              30           Iran   <=50K  ,
#  ' Philippines':        age          workclass  fnlwgt      education  education-num  \
#  151     33            Private  163003      Bachelors             13
#  433     27            Private  116358   Some-college             10
#  654     29          State-gov   71592   Some-college             10
#  880     32            Private  270335      Bachelors             13
#  1280    42        Federal-gov  158926     Assoc-acdm             12
#  ...    ...                ...     ...            ...            ...
#  31786   41            Private  291965   Some-college             10
#  32061   26                  ?  375313   Some-college             10
#  32198   27            Private  100669   Some-college             10
#  32369   53   Self-emp-not-inc  137547    Prof-school             15
#  32427   39        Federal-gov  110622      Bachelors             13
#
#              marital-status        occupation     relationship  \
#  151          Never-married   Exec-managerial   Other-relative
#  433          Never-married      Craft-repair        Own-child
#  654          Never-married      Adm-clerical        Unmarried
#  880     Married-civ-spouse      Adm-clerical   Other-relative
#  1280              Divorced    Prof-specialty        Unmarried
#  ...                    ...               ...              ...
#  31786        Never-married      Tech-support        Unmarried
#  32061        Never-married                 ?        Own-child
#  32198   Married-civ-spouse      Craft-repair          Husband
#  32369        Never-married    Prof-specialty    Not-in-family
#  32427   Married-civ-spouse      Adm-clerical             Wife
#
#                        race      sex  capital-gain  capital-loss  \
#  151     Asian-Pac-Islander   Female             0             0
#  433     Asian-Pac-Islander     Male             0          1980
#  654     Asian-Pac-Islander   Female             0             0
#  880                  White     Male             0             0
#  1280    Asian-Pac-Islander   Female             0             0
#  ...                    ...      ...           ...           ...
#  31786   Asian-Pac-Islander   Female             0             0
#  32061   Asian-Pac-Islander     Male             0             0
#  32198   Asian-Pac-Islander     Male             0             0
#  32369   Asian-Pac-Islander     Male         27828             0
#  32427   Asian-Pac-Islander   Female             0             0
#
#         hours-per-week native-country   <=50K
#  151                40    Philippines   <=50K
#  433                40    Philippines   <=50K
#  654                40    Philippines   <=50K
#  880                40    Philippines    >50K
#  1280               40    Philippines    >50K
#  ...               ...            ...     ...
#  31786              40    Philippines   <=50K
#  32061              40    Philippines   <=50K
#  32198              40    Philippines    >50K
#  32369              40    Philippines    >50K
#  32427              40    Philippines   <=50K
#
#  [198 rows x 15 columns],
#  ' Italy':        age          workclass  fnlwgt      education  education-num  \
#  200     19                  ?  170653        HS-grad              9
#  814     47   Self-emp-not-inc   93208        HS-grad              9
#  1362    51            Private  203435   Some-college             10
#  1654    44            Private  120277      Bachelors             13
#  1673    47            Private  170846     Assoc-acdm             12
# ...
#  3878               40        Vietnam    >50K
#  ...               ...            ...     ...
#  30134              40        Vietnam   <=50K
#  30300              40        Vietnam   <=50K
#  31078              60        Vietnam   <=50K
#  32043              40        Vietnam   <=50K
#  32202              40        Vietnam    >50K
#
#  [67 rows x 15 columns],
#  ' Hong':        age   workclass  fnlwgt      education  education-num  \
#  2654    27     Private  147638      Bachelors             13
#  10187   28   Local-gov  336543     Assoc-acdm             12
#  11945   60     Private  166386           11th              7
#  12095   49     Private  169180        7th-8th              4
#  14213   32     Private  167106        HS-grad              9
#  14671   41           ?  217921            9th              5
#  15643   35     Private  320451        Masters             14
#  16842   36   State-gov  137421      Assoc-voc             11
#  19963   30     Private  328242      Bachelors             13
#  20779   27     Private  298635        Masters             14
#  23916   37     Private  154210   Some-college             10
#  25942   19     Private  277695      Preschool              1
#  27328   29     Private  162551        Masters             14
#  28048   26     Private  167106        HS-grad              9
#  28799   37     Private  121772        HS-grad              9
#  30337   33   State-gov  119628      Doctorate             16
#  30731   26     Private  147638      Bachelors             13
#  30974   40     Private  320451      Doctorate             16
#  32241   33     Private  356015        HS-grad              9
#  32326   28     Private  330466      Bachelors             13
#
#              marital-status          occupation     relationship  \
#  2654         Never-married        Adm-clerical   Other-relative
#  10187   Married-civ-spouse     Protective-serv          Husband
#  11945   Married-civ-spouse   Machine-op-inspct             Wife
#  12095   Married-civ-spouse   Machine-op-inspct             Wife
#  14213   Married-civ-spouse               Sales          Husband
#  14671   Married-civ-spouse                   ?             Wife
#  15643   Married-civ-spouse     Exec-managerial          Husband
#  16842   Married-civ-spouse        Tech-support          Husband
#  19963   Married-civ-spouse     Exec-managerial          Husband
#  20779   Married-civ-spouse      Prof-specialty          Husband
#  23916   Married-civ-spouse        Craft-repair          Husband
#  25942        Never-married     Farming-fishing    Not-in-family
#  27328   Married-civ-spouse      Prof-specialty             Wife
#  28048        Never-married        Craft-repair   Other-relative
#  28799        Never-married        Craft-repair    Not-in-family
#  30337   Married-civ-spouse      Prof-specialty          Husband
#  30731        Never-married        Adm-clerical   Other-relative
#  30974   Married-civ-spouse      Prof-specialty          Husband
#  32241            Separated        Craft-repair    Not-in-family
#  32326        Never-married      Prof-specialty    Not-in-family
#
#                        race      sex  capital-gain  capital-loss  \
#  2654    Asian-Pac-Islander   Female             0             0
#  10187   Asian-Pac-Islander     Male             0             0
#  11945   Asian-Pac-Islander   Female             0             0
#  12095                White   Female             0             0
#  14213   Asian-Pac-Islander     Male             0             0
#  14671   Asian-Pac-Islander   Female             0             0
#  15643   Asian-Pac-Islander     Male             0             0
#  16842   Asian-Pac-Islander     Male             0             0
#  19963   Asian-Pac-Islander     Male             0             0
#  20779   Asian-Pac-Islander     Male             0             0
#  23916   Asian-Pac-Islander     Male             0             0
#  25942                White     Male             0             0
#  27328   Asian-Pac-Islander   Female             0             0
#  28048   Asian-Pac-Islander     Male             0             0
#  28799   Asian-Pac-Islander     Male             0             0
#  30337   Asian-Pac-Islander     Male             0             0
#  30731   Asian-Pac-Islander   Female             0             0
#  30974   Asian-Pac-Islander     Male             0          1977
#  32241   Amer-Indian-Eskimo     Male             0             0
#  32326   Asian-Pac-Islander     Male             0             0
#
#         hours-per-week native-country   <=50K
#  2654               40           Hong   <=50K
#  10187              40           Hong    >50K
#  11945              30           Hong   <=50K
#  12095              40           Hong   <=50K
#  14213              40           Hong   <=50K
#  14671              40           Hong   <=50K
#  15643              65           Hong    >50K
#  16842              37           Hong   <=50K
#  19963              40           Hong    >50K
#  20779              40           Hong    >50K
#  23916              40           Hong   <=50K
#  25942              36           Hong   <=50K
#  27328              40           Hong    >50K
#  28048              40           Hong   <=50K
#  28799              40           Hong   <=50K
#  30337              50           Hong   <=50K
#  30731              40           Hong   <=50K
#  30974              45           Hong    >50K
#  32241              35           Hong   <=50K
#  32326              40           Hong   <=50K  ,
#  ' Ireland':        age          workclass  fnlwgt      education  education-num  \
#  2965    27            Private  163942        HS-grad              9
#  3971    40            Private  120277        HS-grad              9
#  3981    50            Private  139464      Bachelors             13
#  4764    30            Private  112115        HS-grad              9
#  5618    32            Private   94041        HS-grad              9
#  7292    34            Private  118941           11th              7
#  10204   29            Private  183627        HS-grad              9
#  10245   55            Private   90414      Bachelors             13
#  11830   48            Private  160647   Some-college             10
#  11930   32            Private  185027     Assoc-acdm             12
#  12010   51            Private  169364   Some-college             10
#  12900   30            Private  182177        HS-grad              9
#  15085   27            Private  113635        HS-grad              9
#  15157   30            Private  159442        HS-grad              9
#  16989   32            Private   94041      Assoc-voc             11
#  18478   40            Private  115932      Bachelors             13
#  20419   35   Self-emp-not-inc  112497        HS-grad              9
#  20635   23            Private  151888        HS-grad              9
#  21728   68            Private  104438      Bachelors             13
#  25948   46            Private  117313            9th              5
#  26086   32            Private  167990        HS-grad              9
#  26735   30            Private  196342        Masters             14
#  28653   31            Private   63437        HS-grad              9
#  32336   23            Private  194951      Bachelors             13
#
#                 marital-status          occupation     relationship  \
#  2965            Never-married        Craft-repair    Not-in-family
#  3971            Never-married   Handlers-cleaners        Own-child
#  3981                 Divorced      Prof-specialty        Unmarried
#  4764       Married-civ-spouse   Machine-op-inspct          Husband
#  5618       Married-civ-spouse       Other-service          Husband
#  7292            Never-married       Other-service    Not-in-family
#  10204      Married-civ-spouse   Machine-op-inspct          Husband
#  10245   Married-spouse-absent        Craft-repair        Unmarried
#  11830           Never-married     Exec-managerial    Not-in-family
#  11930      Married-civ-spouse        Craft-repair          Husband
#  12010                Divorced   Handlers-cleaners    Not-in-family
#  12900           Never-married       Other-service    Not-in-family
#  15085           Never-married        Craft-repair    Not-in-family
#  15157           Never-married       Other-service    Not-in-family
#  16989           Never-married        Craft-repair    Not-in-family
#  18478      Married-civ-spouse      Prof-specialty          Husband
#  20419      Married-civ-spouse        Craft-repair   Other-relative
#  20635                Divorced        Craft-repair    Not-in-family
#  21728      Married-civ-spouse      Prof-specialty          Husband
#  25948               Separated   Machine-op-inspct    Not-in-family
#  26086      Married-civ-spouse     Exec-managerial          Husband
#  26735           Never-married      Prof-specialty    Not-in-family
#  28653           Never-married     Farming-fishing    Not-in-family
#  32336           Never-married      Prof-specialty    Not-in-family
#
#                        race      sex  capital-gain  capital-loss  \
#  2965                 White     Male             0             0
#  3971                 White     Male             0             0
#  3981                 White   Female             0             0
#  4764                 White     Male             0             0
#  5618                 White     Male             0             0
#  7292                 White   Female             0             0
#  10204                White     Male          3137             0
#  10245                White   Female             0             0
#  11830                White   Female             0             0
#  11930                White     Male             0          1887
#  12010                White   Female             0             0
#  12900                White     Male             0             0
#  15085                White     Male             0             0
#  15157                White   Female             0             0
#  16989                White     Male             0             0
#  18478                White     Male             0             0
#  20419                White     Male             0             0
#  20635                White     Male          4650             0
#  21728                White     Male             0             0
#  25948                White   Female             0             0
#  26086                White     Male             0             0
#  26735                White     Male             0             0
#  28653                White     Male             0             0
#  32336   Asian-Pac-Islander     Male             0             0
#
#         hours-per-week native-country   <=50K
#  2965               35        Ireland   <=50K
#  3971               40        Ireland   <=50K
#  3981               36        Ireland   <=50K
#  4764               60        Ireland    >50K
#  5618               25        Ireland   <=50K
#  7292               40        Ireland   <=50K
#  10204              48        Ireland   <=50K
#  10245              55        Ireland   <=50K
#  11830              40        Ireland    >50K
#  11930              40        Ireland    >50K
#  12010              40        Ireland   <=50K
#  12900              40        Ireland   <=50K
#  15085              35        Ireland   <=50K
#  15157              40        Ireland   <=50K
#  16989              44        Ireland   <=50K
#  18478              60        Ireland    >50K
#  20419              35        Ireland   <=50K
#  20635              50        Ireland   <=50K
#  21728              40        Ireland    >50K
#  25948              40        Ireland   <=50K
#  26086              40        Ireland   <=50K
#  26735              40        Ireland   <=50K
#  28653              40        Ireland   <=50K
#  32336              55        Ireland   <=50K  ,
#  ' Hungary':        age          workclass  fnlwgt      education  education-num  \
#  8561    49            Private  122066        HS-grad              9
#  12528   65            Private  172510   Some-college             10
#  13927   81   Self-emp-not-inc  123959      Bachelors             13
#  15258   60            Private  114263      Bachelors             13
#  17143   28   Self-emp-not-inc  183523        HS-grad              9
#  17734   26            Private  358975   Some-college             10
#  18838   66   Self-emp-not-inc  174995     Assoc-acdm             12
#  21370   30            Private  207668      Bachelors             13
#  22657   54            Private  188186        HS-grad              9
#  23022   24            Private  117779      Bachelors             13
#  27040   57       Self-emp-inc  258883        HS-grad              9
#  27749   55            Private  143266      Assoc-voc             11
#  30345   47            Private  180277        HS-grad              9
#
#              marital-status         occupation     relationship    race  \
#  8561    Married-civ-spouse    Exec-managerial          Husband   White
#  12528              Widowed     Prof-specialty    Not-in-family   White
#  13927              Widowed     Prof-specialty    Not-in-family   White
#  15258             Divorced    Exec-managerial    Not-in-family   White
#  17143   Married-civ-spouse       Craft-repair          Husband   White
#  17734        Never-married    Priv-house-serv    Not-in-family   White
#  18838   Married-civ-spouse       Craft-repair          Husband   White
#  21370        Never-married       Tech-support    Not-in-family   White
#  22657        Never-married      Other-service   Other-relative   White
#  23022        Never-married     Prof-specialty    Not-in-family   White
#  27040   Married-civ-spouse   Transport-moving          Husband   White
#  27749   Married-civ-spouse       Craft-repair          Husband   White
#  30345   Married-civ-spouse       Adm-clerical             Wife   White
#
#             sex  capital-gain  capital-loss  hours-per-week native-country  \
#  8561      Male             0             0              30        Hungary
#  12528   Female          1848             0              20        Hungary
#  13927   Female             0          1668               3        Hungary
#  15258   Female             0             0              40        Hungary
#  17143     Male             0             0              50        Hungary
#  17734   Female             0             0              50        Hungary
#  18838     Male          2290             0              30        Hungary
#  21370     Male             0             0              60        Hungary
#  22657   Female             0             0              20        Hungary
#  23022     Male             0             0              10        Hungary
#  27040     Male          5178             0              60        Hungary
#  27749     Male             0             0              50        Hungary
#  30345   Female             0             0              40        Hungary
#
#          <=50K
#  8561    <=50K
#  12528   <=50K
#  13927   <=50K
#  15258    >50K
#  17143   <=50K
#  17734   <=50K
#  18838   <=50K
#  21370   <=50K
#  22657   <=50K
#  23022   <=50K
#  27040    >50K
#  27749    >50K
#  30345   <=50K  ,
#  ' Holand-Netherlands':        age workclass  fnlwgt      education  education-num  marital-status  \
#  19608   32   Private   27882   Some-college             10   Never-married
#
#                 occupation     relationship    race      sex  capital-gain  \
#  19608   Machine-op-inspct   Other-relative   White   Female             0
#
#         capital-loss  hours-per-week       native-country   <=50K
#  19608          2205              40   Holand-Netherlands   <=50K  }

# %% [markdown]
# <h4>Sex</h4>

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
no_of_males = (df['sex'] == " Male").sum()
no_of_females = (df['sex'] == " Female").sum()

print(f"No of Males: {no_of_males}")
print(f"No of Females: {no_of_females}")
# Out:
# No of Males: 21369
# No of Females: 10608

# %%
males_df = df[df['sex'] == " Male"]
females_df = df[df['sex'] == " Female"]

# %% [markdown]
# <h4>Race</h4>

# %%
races = df['race'].unique()
races
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
race_dfs = []

for race in races:
    race_dfs.append(df[df['race'] == race])

# %%
race_dfs_dict = dict(zip(races, race_dfs))
race_dfs_dict
# Out:
# {' White':        age          workclass  fnlwgt    education  education-num  \
#  0       50   Self-emp-not-inc   83311    Bachelors             13
#  1       38            Private  215646      HS-grad              9
#  4       37            Private  284582      Masters             14
#  6       52   Self-emp-not-inc  209642      HS-grad              9
#  7       31            Private   45781      Masters             14
#  ...    ...                ...     ...          ...            ...
#  32555   27            Private  257302   Assoc-acdm             12
#  32556   40            Private  154374      HS-grad              9
#  32557   58            Private  151910      HS-grad              9
#  32558   22            Private  201490      HS-grad              9
#  32559   52       Self-emp-inc  287927      HS-grad              9
#
#              marital-status          occupation    relationship    race  \
#  0       Married-civ-spouse     Exec-managerial         Husband   White
#  1                 Divorced   Handlers-cleaners   Not-in-family   White
#  4       Married-civ-spouse     Exec-managerial            Wife   White
#  6       Married-civ-spouse     Exec-managerial         Husband   White
#  7            Never-married      Prof-specialty   Not-in-family   White
#  ...                    ...                 ...             ...     ...
#  32555   Married-civ-spouse        Tech-support            Wife   White
#  32556   Married-civ-spouse   Machine-op-inspct         Husband   White
#  32557              Widowed        Adm-clerical       Unmarried   White
#  32558        Never-married        Adm-clerical       Own-child   White
#  32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#             sex  capital-gain  capital-loss  hours-per-week  native-country  \
#  0         Male             0             0              13   United-States
#  1         Male             0             0              40   United-States
#  4       Female             0             0              40   United-States
#  6         Male             0             0              45   United-States
#  7       Female         14084             0              50   United-States
#  ...        ...           ...           ...             ...             ...
#  32555   Female             0             0              38   United-States
#  32556     Male             0             0              40   United-States
#  32557   Female             0             0              40   United-States
#  32558     Male             0             0              20   United-States
#  32559   Female         15024             0              40   United-States
#
#          <=50K
#  0       <=50K
#  1       <=50K
#  4       <=50K
#  6        >50K
#  7        >50K
#  ...       ...
#  32555   <=50K
#  32556    >50K
#  32557   <=50K
#  32558   <=50K
#  32559    >50K
#
#  [27429 rows x 15 columns],
#  ' Black':        age workclass  fnlwgt      education  education-num  \
#  2       53   Private  234721           11th              7
#  3       28   Private  338409      Bachelors             13
#  5       49   Private  160187            9th              5
#  9       37   Private  280464   Some-college             10
#  12      32   Private  205019     Assoc-acdm             12
#  ...    ...       ...     ...            ...            ...
#  32520   33   Private  273243        HS-grad              9
#  32534   22   Private  325033           12th              8
#  32536   30   Private  345898        HS-grad              9
#  32537   38   Private  139180      Bachelors             13
#  32540   41         ?  202822        HS-grad              9
#
#                 marital-status          occupation    relationship    race  \
#  2          Married-civ-spouse   Handlers-cleaners         Husband   Black
#  3          Married-civ-spouse      Prof-specialty            Wife   Black
#  5       Married-spouse-absent       Other-service   Not-in-family   Black
#  9          Married-civ-spouse     Exec-managerial         Husband   Black
#  12              Never-married               Sales   Not-in-family   Black
#  ...                       ...                 ...             ...     ...
#  32520      Married-civ-spouse        Craft-repair         Husband   Black
#  32534           Never-married     Protective-serv       Own-child   Black
#  32536           Never-married        Craft-repair   Not-in-family   Black
#  32537                Divorced      Prof-specialty       Unmarried   Black
#  32540               Separated                   ?   Not-in-family   Black
#
#             sex  capital-gain  capital-loss  hours-per-week  native-country  \
#  2         Male             0             0              40   United-States
#  3       Female             0             0              40            Cuba
#  5       Female             0             0              16         Jamaica
#  9         Male             0             0              80   United-States
#  12        Male             0             0              50   United-States
#  ...        ...           ...           ...             ...             ...
#  32520     Male             0             0              40   United-States
#  32534     Male             0             0              35   United-States
#  32536     Male             0             0              46   United-States
#  32537   Female         15020             0              45   United-States
#  32540   Female             0             0              32   United-States
#
#          <=50K
#  2       <=50K
#  3       <=50K
#  5       <=50K
#  9        >50K
#  12      <=50K
#  ...       ...
#  32520   <=50K
#  32534   <=50K
#  32536   <=50K
#  32537    >50K
#  32540   <=50K
#
#  [3028 rows x 15 columns],
#  ' Asian-Pac-Islander':        age      workclass  fnlwgt      education  education-num  \
#  10      30      State-gov  141297      Bachelors             13
#  26      54              ?  180211   Some-college             10
#  138     49        Private   81973   Some-college             10
#  151     33        Private  163003      Bachelors             13
#  161     44   Self-emp-inc   78374        Masters             14
#  ...    ...            ...     ...            ...            ...
#  32456   33        Private  139057        Masters             14
#  32485   24        Private  216984   Some-college             10
#  32530   30              ?   33811      Bachelors             13
#  32532   54        Private  337992      Bachelors             13
#  32552   32        Private  116138        Masters             14
#
#              marital-status        occupation     relationship  \
#  10      Married-civ-spouse    Prof-specialty          Husband
#  26      Married-civ-spouse                 ?          Husband
#  138     Married-civ-spouse      Craft-repair          Husband
#  151          Never-married   Exec-managerial   Other-relative
#  161               Divorced   Exec-managerial        Unmarried
#  ...                    ...               ...              ...
#  32456   Married-civ-spouse      Tech-support          Husband
#  32485   Married-civ-spouse     Other-service        Own-child
#  32530        Never-married                 ?    Not-in-family
#  32532   Married-civ-spouse   Exec-managerial          Husband
#  32552        Never-married      Tech-support    Not-in-family
#
#                        race      sex  capital-gain  capital-loss  \
#  10      Asian-Pac-Islander     Male             0             0
#  26      Asian-Pac-Islander     Male             0             0
#  138     Asian-Pac-Islander     Male             0             0
#  151     Asian-Pac-Islander   Female             0             0
#  161     Asian-Pac-Islander   Female             0             0
#  ...                    ...      ...           ...           ...
#  32456   Asian-Pac-Islander     Male             0             0
#  32485   Asian-Pac-Islander   Female             0             0
#  32530   Asian-Pac-Islander   Female             0             0
#  32532   Asian-Pac-Islander     Male             0             0
#  32552   Asian-Pac-Islander     Male             0             0
#
#         hours-per-week  native-country   <=50K
#  10                 40           India    >50K
#  26                 60           South    >50K
#  138                40   United-States    >50K
#  151                40     Philippines   <=50K
#  161                40   United-States   <=50K
#  ...               ...             ...     ...
#  32456              50   United-States    >50K
#  32485              35   United-States   <=50K
#  32530              99   United-States   <=50K
#  32532              50           Japan    >50K
#  32552              11          Taiwan   <=50K
#
#  [956 rows x 15 columns],
#  ' Amer-Indian-Eskimo':        age workclass  fnlwgt      education  education-num  \
#  14      34   Private  245487        7th-8th              4
#  211     35   Private  153790   Some-college             10
#  225     60         ?   24215           10th              6
#  446     51   Private   56915        HS-grad              9
#  515     25   Private  267044   Some-college             10
#  ...    ...       ...     ...            ...            ...
#  32230   44   Private   33105        HS-grad              9
#  32241   33   Private  356015        HS-grad              9
#  32248   35   Private   91839      Bachelors             13
#  32424   23   Private  180771        1st-4th              2
#  32550   32   Private   34066           10th              6
#
#              marital-status          occupation    relationship  \
#  14      Married-civ-spouse    Transport-moving         Husband
#  211          Never-married               Sales   Not-in-family
#  225               Divorced                   ?   Not-in-family
#  446     Married-civ-spouse        Craft-repair         Husband
#  515          Never-married        Adm-clerical   Not-in-family
#  ...                    ...                 ...             ...
#  32230   Married-civ-spouse     Exec-managerial         Husband
#  32241            Separated        Craft-repair   Not-in-family
#  32248   Married-civ-spouse       Other-service         Husband
#  32424   Married-civ-spouse   Machine-op-inspct            Wife
#  32550   Married-civ-spouse   Handlers-cleaners         Husband
#
#                        race      sex  capital-gain  capital-loss  \
#  14      Amer-Indian-Eskimo     Male             0             0
#  211     Amer-Indian-Eskimo   Female             0             0
#  225     Amer-Indian-Eskimo   Female             0             0
#  446     Amer-Indian-Eskimo     Male             0             0
#  515     Amer-Indian-Eskimo   Female             0             0
#  ...                    ...      ...           ...           ...
#  32230   Amer-Indian-Eskimo     Male             0             0
#  32241   Amer-Indian-Eskimo     Male             0             0
#  32248   Amer-Indian-Eskimo     Male          7688             0
#  32424   Amer-Indian-Eskimo   Female             0             0
#  32550   Amer-Indian-Eskimo     Male             0             0
#
#         hours-per-week  native-country   <=50K
#  14                 45          Mexico   <=50K
#  211                40   United-States   <=50K
#  225                10   United-States   <=50K
#  446                40   United-States   <=50K
#  515                20   United-States   <=50K
#  ...               ...             ...     ...
#  32230              40   United-States   <=50K
#  32241              35            Hong   <=50K
#  32248              20   United-States    >50K
#  32424              35          Mexico   <=50K
#  32550              40   United-States   <=50K
#
#  [311 rows x 15 columns],
#  ' Other':        age workclass  fnlwgt      education  education-num  \
#  49      25   Private   32275   Some-college             10
#  232     33   Private  110978   Some-college             10
#  355     65   Private  161400           11th              7
#  403     28   Private  166481        7th-8th              4
#  529     44   Private  109339           11th              7
#  ...    ...       ...     ...            ...            ...
#  32020   46   Private  211226     Assoc-acdm             12
#  32074   27         ?  147638        Masters             14
#  32262   27   Private  176761        HS-grad              9
#  32431   36   Private  208068      Preschool              1
#  32543   31   Private  199655        Masters             14
#
#              marital-status          occupation     relationship    race  \
#  49      Married-civ-spouse     Exec-managerial             Wife   Other
#  232               Divorced        Craft-repair   Other-relative   Other
#  355                Widowed       Other-service        Unmarried   Other
#  403     Married-civ-spouse   Handlers-cleaners          Husband   Other
#  529               Divorced   Machine-op-inspct        Unmarried   Other
#  ...                    ...                 ...              ...     ...
#  32020   Married-civ-spouse    Transport-moving          Husband   Other
#  32074        Never-married                   ?    Not-in-family   Other
#  32262        Never-married        Craft-repair   Other-relative   Other
#  32431             Divorced       Other-service    Not-in-family   Other
#  32543             Divorced       Other-service    Not-in-family   Other
#
#             sex  capital-gain  capital-loss  hours-per-week  native-country  \
#  49      Female             0             0              40   United-States
#  232     Female             0             0              40   United-States
#  355       Male             0             0              40   United-States
#  403       Male             0          2179              40     Puerto-Rico
#  529     Female             0             0              46     Puerto-Rico
#  ...        ...           ...           ...             ...             ...
#  32020     Male             0             0              36   United-States
#  32074   Female             0             0              40           Japan
#  32262     Male             0             0              40       Nicaragua
#  32431     Male             0             0              72          Mexico
#  32543   Female             0             0              30   United-States
#
#          <=50K
#  49      <=50K
#  232     <=50K
#  355     <=50K
#  403     <=50K
#  529     <=50K
#  ...       ...
#  32020   <=50K
#  32074   <=50K
#  32262   <=50K
#  32431   <=50K
#  32543   <=50K
#
#  [253 rows x 15 columns]}

# %% [markdown]
# <h3>2. Merge two subsets (all people who are from USA or are white)</h3>

# %%
usa_or_white_fd = pd.concat([country_dfs_dict[' United-States'], race_dfs_dict[' White']])

# %%
usa_or_white_fd
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 4       37            Private  284582      Masters             14
# 6       52   Self-emp-not-inc  209642      HS-grad              9
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# 6       Married-civ-spouse     Exec-managerial         Husband   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 4       Female             0             0              40   United-States
# 6         Male             0             0              45   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#         <=50K
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 4       <=50K
# 6        >50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [56598 rows x 15 columns]

# %% [markdown]
# <h3>3. Sort Data using age</h3>

# %%
sorted_df = df.sort_values(by='age', ascending=False)

# %%
sorted_df
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 19488   90            Private   84553        HS-grad              9
# 2890    90            Private  171956   Some-college             10
# 18412   90            Private  313749      Bachelors             13
# 12974   90            Private  250832           10th              6
# 6231    90   Self-emp-not-inc  155981      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 12291   17            Private  169037           11th              7
# 31958   17            Private   24090        HS-grad              9
# 10294   17            Private  228399           11th              7
# 26589   17            Private   52486           11th              7
# 22297   17            Private  134480           11th              7
#
#             marital-status          occupation relationship    race      sex  \
# 19488   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 2890             Separated        Adm-clerical    Own-child   White   Female
# 18412        Never-married      Prof-specialty    Own-child   White   Female
# 12974   Married-civ-spouse     Exec-managerial      Husband   White     Male
# 6231    Married-civ-spouse      Prof-specialty      Husband   White     Male
# ...                    ...                 ...          ...     ...      ...
# 12291        Never-married   Handlers-cleaners    Own-child   White     Male
# 31958        Never-married     Exec-managerial    Own-child   White   Female
# 10294        Never-married       Other-service    Own-child   White   Female
# 26589        Never-married       Other-service    Own-child   White   Female
# 22297        Never-married     Priv-house-serv    Own-child   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country   <=50K
# 19488             0             0              40   United-States   <=50K
# 2890              0             0              40     Puerto-Rico   <=50K
# 18412             0             0              10   United-States   <=50K
# 12974             0             0              40   United-States   <=50K
# 6231          10566             0              50   United-States   <=50K
# ...             ...           ...             ...             ...     ...
# 12291             0             0              40   United-States   <=50K
# 31958             0             0              35   United-States   <=50K
# 10294             0             0               7   United-States   <=50K
# 26589             0             0              12   United-States   <=50K
# 22297             0             0              25   United-States   <=50K
#
# [31977 rows x 15 columns]

# %% [markdown]
# <h3>4. Transposing Data</h3>

# %%
transposed_df = df.transpose()

# %%
transposed_df
# Out:
#                               0                   1                    2      \
# age                              50                  38                   53
# workclass          Self-emp-not-inc             Private              Private
# fnlwgt                        83311              215646               234721
# education                 Bachelors             HS-grad                 11th
# education-num                    13                   9                    7
# marital-status   Married-civ-spouse            Divorced   Married-civ-spouse
# occupation          Exec-managerial   Handlers-cleaners    Handlers-cleaners
# relationship                Husband       Not-in-family              Husband
# race                          White               White                Black
# sex                            Male                Male                 Male
# capital-gain                      0                   0                    0
# capital-loss                      0                   0                    0
# hours-per-week                   13                  40                   40
# native-country        United-States       United-States        United-States
# <=50K                         <=50K               <=50K                <=50K
#
#                               3                    4      \
# age                              28                   37
# workclass                   Private              Private
# fnlwgt                       338409               284582
# education                 Bachelors              Masters
# education-num                    13                   14
# marital-status   Married-civ-spouse   Married-civ-spouse
# occupation           Prof-specialty      Exec-managerial
# relationship                   Wife                 Wife
# race                          Black                White
# sex                          Female               Female
# capital-gain                      0                    0
# capital-loss                      0                    0
# hours-per-week                   40                   40
# native-country                 Cuba        United-States
# <=50K                         <=50K                <=50K
#
#                                  5                    6                7      \
# age                                 49                   52               31
# workclass                      Private     Self-emp-not-inc          Private
# fnlwgt                          160187               209642            45781
# education                          9th              HS-grad          Masters
# education-num                        5                    9               14
# marital-status   Married-spouse-absent   Married-civ-spouse    Never-married
# occupation               Other-service      Exec-managerial   Prof-specialty
# relationship             Not-in-family              Husband    Not-in-family
# race                             Black                White            White
# sex                             Female                 Male           Female
# capital-gain                         0                    0            14084
# capital-loss                         0                    0                0
# hours-per-week                      16                   45               50
# native-country                 Jamaica        United-States    United-States
# <=50K                            <=50K                 >50K             >50K
#
#                               8                    9      ...  \
# age                              42                   37  ...
# workclass                   Private              Private  ...
# fnlwgt                       159449               280464  ...
# education                 Bachelors         Some-college  ...
# education-num                    13                   10  ...
# marital-status   Married-civ-spouse   Married-civ-spouse  ...
# occupation          Exec-managerial      Exec-managerial  ...
# relationship                Husband              Husband  ...
# race                          White                Black  ...
# sex                            Male                 Male  ...
# capital-gain                   5178                    0  ...
# capital-loss                      0                    0  ...
# hours-per-week                   40                   80  ...
# native-country        United-States        United-States  ...
# <=50K                          >50K                 >50K  ...
#
#                               32550                32551                32552  \
# age                              32                   43                   32
# workclass                   Private              Private              Private
# fnlwgt                        34066                84661               116138
# education                      10th            Assoc-voc              Masters
# education-num                     6                   11                   14
# marital-status   Married-civ-spouse   Married-civ-spouse        Never-married
# occupation        Handlers-cleaners                Sales         Tech-support
# relationship                Husband              Husband        Not-in-family
# race             Amer-Indian-Eskimo                White   Asian-Pac-Islander
# sex                            Male                 Male                 Male
# capital-gain                      0                    0                    0
# capital-loss                      0                    0                    0
# hours-per-week                   40                   45                   11
# native-country        United-States        United-States               Taiwan
# <=50K                         <=50K                <=50K                <=50K
#
#                               32553             32554                32555  \
# age                              53                22                   27
# workclass                   Private           Private              Private
# fnlwgt                       321865            310152               257302
# education                   Masters      Some-college           Assoc-acdm
# education-num                    14                10                   12
# marital-status   Married-civ-spouse     Never-married   Married-civ-spouse
# occupation          Exec-managerial   Protective-serv         Tech-support
# relationship                Husband     Not-in-family                 Wife
# race                          White             White                White
# sex                            Male              Male               Female
# capital-gain                      0                 0                    0
# capital-loss                      0                 0                    0
# hours-per-week                   40                40                   38
# native-country        United-States     United-States        United-States
# <=50K                          >50K             <=50K                <=50K
#
#                               32556           32557           32558  \
# age                              40              58              22
# workclass                   Private         Private         Private
# fnlwgt                       154374          151910          201490
# education                   HS-grad         HS-grad         HS-grad
# education-num                     9               9               9
# marital-status   Married-civ-spouse         Widowed   Never-married
# occupation        Machine-op-inspct    Adm-clerical    Adm-clerical
# relationship                Husband       Unmarried       Own-child
# race                          White           White           White
# sex                            Male          Female            Male
# capital-gain                      0               0               0
# capital-loss                      0               0               0
# hours-per-week                   40              40              20
# native-country        United-States   United-States   United-States
# <=50K                          >50K           <=50K           <=50K
#
#                               32559
# age                              52
# workclass              Self-emp-inc
# fnlwgt                       287927
# education                   HS-grad
# education-num                     9
# marital-status   Married-civ-spouse
# occupation          Exec-managerial
# relationship                   Wife
# race                          White
# sex                          Female
# capital-gain                  15024
# capital-loss                      0
# hours-per-week                   40
# native-country        United-States
# <=50K                          >50K
#
# [15 rows x 31977 columns]
