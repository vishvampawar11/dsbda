# %% [markdown]
# <p><b>Perform the following operations using Python on the Iris data sets</b></p>
# <ol>
#     <li>Create data subsets for different species</li>
#     <li>Merge two subsets</li>
#     <li>Sort Data Petal Length</li>
#     <li>Transposing Data</li>
#     <li>Melting Data to long format</li>
#     <li>Casting data to wide format</li>
# </ol>

# %%
import pandas as pd

# %%
headers = ["sepal length(cm)", "sepal width(cm)", "petal length(cm)", "petal width(cm)", "class"]

# %%
df = pd.read_csv("datasets/Iris/iris.csv", names=headers, header=None)

# %%
df
# Out:
#      sepal length(cm)  sepal width(cm)  petal length(cm)  petal width(cm)  \
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#         sepal length(cm)  sepal width(cm)  petal length(cm)  petal width(cm)  \
# count              150.0            150.0             150.0            150.0
# unique              36.0             24.0              44.0             23.0
# top                  5.0              3.0               1.5              0.2
# freq                10.0             26.0              14.0             27.0
#
#               class
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
df.isna().sum()
# Out:
# sepal length(cm)    0
# sepal width(cm)     0
# petal length(cm)    0
# petal width(cm)     0
# class               0
# dtype: int64

# %% [markdown]
# <h3>1. Create data subsets for different species</h3>

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
no_of_iris_setosa = (df['class'] == "Iris-setosa").sum()
no_of_iris_versicolor = (df['class'] == "Iris-versicolor").sum()
no_of_iris_virginica = (df['class'] == "Iris-virginica").sum()

print(f"No of Iris-setosa: {no_of_iris_setosa}")
print(f"No of Iris-versicolor: {no_of_iris_versicolor}")
print(f"No of Iris-verginica: {no_of_iris_virginica}")
# Out:
# No of Iris-setosa: 50
# No of Iris-versicolor: 50
# No of Iris-verginica: 50

# %%
iris_setosa_df = df[df['class'] == "Iris-setosa"]
iris_versicolor_df = df[df['class'] == "Iris-versicolor"]
iris_virginica_df = df[df['class'] == "Iris-virginica"]

# %% [markdown]
# <h3>2. Merge two subsets (Iris-setosa and Iris-versicolor)</h3>

# %%
merged_df = pd.concat([iris_setosa_df, iris_versicolor_df])

# %%
merged_df
# Out:
#    sepal length(cm) sepal width(cm) petal length(cm) petal width(cm)  \
# 0               4.9             3.0              1.4             0.2
# 1               4.7             3.2              1.3             0.2
# 2               4.6             3.1              1.5             0.2
# 3               5.0             3.6              1.4             0.2
# 4               5.4             3.9              1.7             0.4
# ..              ...             ...              ...             ...
# 94              5.7             3.0              4.2             1.2
# 95              5.7             2.9              4.2             1.3
# 96              6.2             2.9              4.3             1.3
# 97              5.1             2.5              3.0             1.1
# 98              5.7             2.8              4.1             1.3
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 94  Iris-versicolor
# 95  Iris-versicolor
# 96  Iris-versicolor
# 97  Iris-versicolor
# 98  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
merged_df.shape
# Out:
# (100, 5)

# %% [markdown]
# <h3>3. Sort Data Petal Length</h3>

# %% [markdown]
# <h4>Converting data type of patel length from string to float</h4>

# %%
df['petal length(cm)'].dtype
# Out:
# dtype('O')

# %%
df['petal length(cm)'] =  pd.to_numeric(df['petal length(cm)'])

# %%
sorted_df = df.sort_values(by="petal length(cm)")

# %%
sorted_df
# Out:
#     sepal length(cm) sepal width(cm)  petal length(cm) petal width(cm)  \
# 21               4.6             3.6               1.0             0.2
# 12               4.3             3.0               1.1             0.1
# 13               5.8             4.0               1.2             0.2
# 34               5.0             3.2               1.2             0.2
# 35               5.5             3.5               1.3             0.2
# ..               ...             ...               ...             ...
# 130              7.9             3.8               6.4             2.0
# 104              7.6             3.0               6.6             2.1
# 121              7.7             2.8               6.7             2.0
# 116              7.7             3.8               6.7             2.2
# 117              7.7             2.6               6.9             2.3
#
#               class
# 21      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 34      Iris-setosa
# 35      Iris-setosa
# ..              ...
# 130  Iris-virginica
# 104  Iris-virginica
# 121  Iris-virginica
# 116  Iris-virginica
# 117  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <h3>4. Transposing Data</h3>

# %%
transposed_df = df.transpose()

# %%
transposed_df
# Out:
#                           0            1            2            3    \
# sepal length(cm)          4.9          4.7          4.6          5.0
# sepal width(cm)           3.0          3.2          3.1          3.6
# petal length(cm)          1.4          1.3          1.5          1.4
# petal width(cm)           0.2          0.2          0.2          0.2
# class             Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                           4            5            6            7    \
# sepal length(cm)          5.4          4.6          5.0          4.4
# sepal width(cm)           3.9          3.4          3.4          2.9
# petal length(cm)          1.7          1.4          1.5          1.4
# petal width(cm)           0.4          0.3          0.2          0.2
# class             Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                           8            9    ...             140  \
# sepal length(cm)          4.9          5.4  ...             6.9
# sepal width(cm)           3.1          3.7  ...             3.1
# petal length(cm)          1.5          1.5  ...             5.1
# petal width(cm)           0.1          0.2  ...             2.3
# class             Iris-setosa  Iris-setosa  ...  Iris-virginica
#
#                              141             142             143  \
# sepal length(cm)             5.8             6.8             6.7
# sepal width(cm)              2.7             3.2             3.3
# petal length(cm)             5.1             5.9             5.7
# petal width(cm)              1.9             2.3             2.5
# class             Iris-virginica  Iris-virginica  Iris-virginica
#
#                              144             145             146  \
# sepal length(cm)             6.7             6.3             6.5
# sepal width(cm)              3.0             2.5             3.0
# petal length(cm)             5.2             5.0             5.2
# petal width(cm)              2.3             1.9             2.0
# class             Iris-virginica  Iris-virginica  Iris-virginica
#
#                              147             148          149
# sepal length(cm)             6.2             5.9          5.1
# sepal width(cm)              3.4             3.0          3.5
# petal length(cm)             5.4             5.1          1.4
# petal width(cm)              2.3             1.8          0.2
# class             Iris-virginica  Iris-virginica  Iris-setosa
#
# [5 rows x 150 columns]

# %% [markdown]
# <h3>5. Melting data into long format</h3>

# %%
melted_df = pd.melt(df, id_vars=['class'], var_name="Petal Properties", value_name="value")

# %%
melted_df
# Out:
#               class  Petal Properties value
# 0       Iris-setosa  sepal length(cm)   4.9
# 1       Iris-setosa  sepal length(cm)   4.7
# 2       Iris-setosa  sepal length(cm)   4.6
# 3       Iris-setosa  sepal length(cm)   5.0
# 4       Iris-setosa  sepal length(cm)   5.4
# ..              ...               ...   ...
# 595  Iris-virginica   petal width(cm)   1.9
# 596  Iris-virginica   petal width(cm)   2.0
# 597  Iris-virginica   petal width(cm)   2.3
# 598  Iris-virginica   petal width(cm)   1.8
# 599     Iris-setosa   petal width(cm)   0.2
#
# [600 rows x 3 columns]

# %% [markdown]
# <h3>6. Casting data into long format</h3>

# %%
temp_df = df.iloc[[1, 51, 101], :]
temp_df
# Out:
#     sepal length(cm) sepal width(cm)  petal length(cm) petal width(cm)  \
# 1                4.7             3.2               1.3             0.2
# 51               6.9             3.1               4.9             1.5
# 101              7.1             3.0               5.9             2.1
#
#                class
# 1        Iris-setosa
# 51   Iris-versicolor
# 101   Iris-virginica

# %%
pivoted_df = temp_df.pivot(index="class",columns="sepal width(cm)")
pivoted_df
# Out:
#                 sepal length(cm)           petal length(cm)            \
# sepal width(cm)              3.0  3.1  3.2              3.0  3.1  3.2
# class
# Iris-setosa                  NaN  NaN  4.7              NaN  NaN  1.3
# Iris-versicolor              NaN  6.9  NaN              NaN  4.9  NaN
# Iris-virginica               7.1  NaN  NaN              5.9  NaN  NaN
#
#                 petal width(cm)
# sepal width(cm)             3.0  3.1  3.2
# class
# Iris-setosa                 NaN  NaN  0.2
# Iris-versicolor             NaN  1.5  NaN
# Iris-virginica              2.1  NaN  NaN
